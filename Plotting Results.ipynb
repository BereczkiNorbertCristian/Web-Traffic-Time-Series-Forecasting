# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import matplotlib.patches as mpatches

# %%
def readFile(filename):
    lst = []
    with open(filename,"r") as f:
        for line in f:
            x = float(line.rstrip("\n"))
            if x > 10: continue
            if math.isnan(x): continue
            lst.append(x)
    return lst

# %%
out_root = "OUT/"
lstTFT = readFile(out_root + "TFT.out")
lstTFF = readFile(out_root + "TFF.out")
lstFFF = readFile(out_root + "FFF.out")
lstFFT = readFile(out_root + "FFT.out")
lstFTF = readFile(out_root + "FTF.out")

# %%
tft_pd = pd.DataFrame(lstTFT)
tff_pd = pd.DataFrame(lstTFF)
fff_pd = pd.DataFrame(lstFFF)
fft_pd = pd.DataFrame(lstFFT)
ftf_pd = pd.DataFrame(lstFTF)

# %%
plt.figure(figsize=(15,20))

plt.subplot(5,1,1)
plt.title('Daily=true, Weekly=false, Yearly=true')
plt.hist(lstTFT,bins=10)
plt.axvline(tft_pd.mean()[0], color='r', linestyle='dashed', linewidth=2)
plt.axvline(tft_pd.median()[0], color='g', linestyle='dashed', linewidth=2)
tft_std = tft_pd.std()
plt.axvline(tft_pd.median()[0] + tft_std[0], color='y', linestyle='dashed', linewidth=2)
plt.axvline(tft_pd.median()[0] - tft_std[0], color='y', linestyle='dashed', linewidth=2)

plt.subplot(5,1,2)
plt.title('Daily=true, Weekly=false, Yearly=false')
plt.hist(lstTFF,bins=10)
plt.axvline(tff_pd.mean()[0], color='r', linestyle='dashed', linewidth=2)
plt.axvline(tff_pd.median()[0], color='g', linestyle='dashed', linewidth=2)
tff_std = tft_pd.std()
plt.axvline(tff_pd.median()[0] + tff_std[0], color='y', linestyle='dashed', linewidth=2)
plt.axvline(tff_pd.median()[0] - tff_std[0], color='y', linestyle='dashed', linewidth=2)


plt.subplot(5,1,3)
plt.title('Daily=false, Weekly=false, Yearly=false')
plt.hist(lstFFF,bins=10)
plt.axvline(fff_pd.mean()[0], color='r', linestyle='dashed', linewidth=2)
plt.axvline(fff_pd.median()[0], color='g', linestyle='dashed', linewidth=2)
fff_std = fff_pd.std()
plt.axvline(fff_pd.median()[0] + fff_std[0], color='y', linestyle='dashed', linewidth=2)
plt.axvline(fff_pd.median()[0] - fff_std[0], color='y', linestyle='dashed', linewidth=2)


plt.subplot(5,1,4)
plt.title('Daily=false, Weekly=false, Yearly=true')
plt.hist(lstFFT,bins=10)
plt.axvline(fft_pd.mean()[0], color='r', linestyle='dashed', linewidth=2)
plt.axvline(fft_pd.median()[0], color='g', linestyle='dashed', linewidth=2)
fft_std = fft_pd.std()
plt.axvline(fft_pd.median()[0] + fft_std[0], color='y', linestyle='dashed', linewidth=2)
plt.axvline(fft_pd.median()[0] - fft_std[0], color='y', linestyle='dashed', linewidth=2)


plt.subplot(5,1,5)
plt.title('Daily=false, Weekly=true, Yearly=false')
plt.hist(lstFTF,bins=10)
plt.axvline(ftf_pd.mean()[0], color='r', linestyle='dashed', linewidth=2)
plt.axvline(ftf_pd.median()[0], color='g', linestyle='dashed', linewidth=2)
ftf_std = ftf_pd.std()
plt.axvline(ftf_pd.median()[0] + ftf_std[0], color='y', linestyle='dashed', linewidth=2)
plt.axvline(ftf_pd.median()[0] - ftf_std[0], color='y', linestyle='dashed', linewidth=2)


plt.savefig("FIGS/comparrison.png")
plt.show()

# %%
tft_pd.plot(kind='kde',figsize=(15,5))
plt.axvline(tft_pd.mean()[0], color='r', linestyle='dashed', linewidth=2)
plt.axvline(tft_pd.median()[0], color='g', linestyle='dashed', linewidth=2)

tff_pd.plot(kind='kde',figsize=(15,5))
plt.axvline(tff_pd.mean()[0], color='r', linestyle='dashed', linewidth=2)
plt.axvline(tff_pd.median()[0], color='g', linestyle='dashed', linewidth=2)

fff_pd.plot(kind='kde',figsize=(15,5))
plt.axvline(fff_pd.mean()[0], color='r', linestyle='dashed', linewidth=2)
plt.axvline(fff_pd.median()[0], color='g', linestyle='dashed', linewidth=2)

fft_pd.plot(kind='kde',figsize=(15,5))
plt.axvline(fft_pd.mean()[0], color='r', linestyle='dashed', linewidth=2)
plt.axvline(fft_pd.median()[0], color='g', linestyle='dashed', linewidth=2)

ftf_pd.plot(kind='kde',figsize=(15,5))
plt.axvline(ftf_pd.mean()[0], color='r', linestyle='dashed', linewidth=2)
plt.axvline(ftf_pd.median()[0], color='g', linestyle='dashed', linewidth=2)

plt.show()

# %%
lstTFT = readFile(out_root + "TFT.out")
tft_pd = pd.DataFrame(lstTFT)
plt.figure(figsize=(15,5))
plt.title('Daily=true, Weekly=false, Yearly=true')
plt.hist(lstTFT,bins=20)
plt.axvline(tft_pd.mean()[0], color='r', linestyle='dashed', linewidth=2)
plt.axvline(tft_pd.median()[0], color='g', linestyle='dashed', linewidth=2)
plt.show()

# %%
def danyParser(filename):
    ret = []
    with open(filename,"r") as f:
        for line in f:
            ret = list(map(float,line.split(",")))
    return ret

# %%
deep1 = danyParser("DANI/deep.out")

deep_pd = pd.DataFrame(deep1)

# %%
plt.figure(figsize=(15,20))

plt.subplot(3,1,1)
plt.hist(lstTFT,bins=10)
plt.axvline(deep_pd.mean()[0], color='r', linestyle='dashed', linewidth=2)
plt.axvline(deep_pd.median()[0], color='g', linestyle='dashed', linewidth=2)
deep_std = deep_pd.std()
plt.axvline(deep_pd.median()[0] + deep_std[0], color='y', linestyle='dashed', linewidth=2)
plt.axvline(deep_pd.median()[0] - deep_std[0], color='y', linestyle='dashed', linewidth=2)


plt.subplot(3,1,2)
plt.title('Daily=false, Weekly=false, Yearly=false')
plt.hist(lstFFF,bins=10)
plt.axvline(fff_pd.mean()[0], color='r', linestyle='dashed', linewidth=2)
plt.axvline(fff_pd.median()[0], color='g', linestyle='dashed', linewidth=2)
fff_std = fff_pd.std()
plt.axvline(fff_pd.median()[0] + fff_std[0], color='y', linestyle='dashed', linewidth=2)
plt.axvline(fff_pd.median()[0] - fff_std[0], color='y', linestyle='dashed', linewidth=2)

plt.subplot(3,1,3)
plt.title('Daily=false, Weekly=true, Yearly=false')
plt.hist(lstFTF,bins=10)
plt.axvline(ftf_pd.mean()[0], color='r', linestyle='dashed', linewidth=2)
plt.axvline(ftf_pd.median()[0], color='g', linestyle='dashed', linewidth=2)
ftf_std = ftf_pd.std()
plt.axvline(ftf_pd.median()[0] + ftf_std[0], color='y', linestyle='dashed', linewidth=2)
plt.axvline(ftf_pd.median()[0] - ftf_std[0], color='y', linestyle='dashed', linewidth=2)

plt.show()
