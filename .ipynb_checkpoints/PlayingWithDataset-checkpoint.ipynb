# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train_1.csv')
df
# Out:
#                                                      Page  2015-07-01  \
# 0                 2NE1_zh.wikipedia.org_all-access_spider        18.0
# 1                  2PM_zh.wikipedia.org_all-access_spider        11.0
# 2                   3C_zh.wikipedia.org_all-access_spider         1.0
# 3              4minute_zh.wikipedia.org_all-access_spider        35.0
# 4       52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...         NaN
# 5                 5566_zh.wikipedia.org_all-access_spider        12.0
# 6               91Days_zh.wikipedia.org_all-access_spider         NaN
# 7                A'N'D_zh.wikipedia.org_all-access_spider       118.0
# 8                AKB48_zh.wikipedia.org_all-access_spider         5.0
# 9                ASCII_zh.wikipedia.org_all-access_spider         6.0
# 10               ASTRO_zh.wikipedia.org_all-access_spider         NaN
# 11      Ahq_e-Sports_Club_zh.wikipedia.org_all-access_...         2.0
# ...

# %%
row = df.loc[0][1:]

# %%
row.plot(kind='line',figsize=(15,5))
plt.show()

# %%
row.plot(kind='box',figsize=(15,5))
plt.show()

# %%
plt.subplot(3,1,1)
row = df.loc[1][1:]
row.plot(kind='line',figsize=(15,5))
plt.subplot(3,1,2)
row = df.loc[2][1:]
row.plot(kind='line',figsize=(15,5))
plt.subplot(3,1,3)
row = df.loc[3][1:]
row.plot(kind='line',figsize=(15,5))
plt.show()

# %%
plt.subplot(3,1,1)
row = df.loc[4][1:]
row.plot(kind='line',figsize=(15,5))
plt.subplot(3,1,2)
row = df.loc[5][1:]
row.plot(kind='line',figsize=(15,5))
plt.subplot(3,1,3)
row = df.loc[6][1:]
row.plot(kind='line',figsize=(15,5))
plt.show()

# %%
plt.subplot(3,1,1)
row = df.loc[7][1:]
row.plot(kind='line',figsize=(15,5))
plt.subplot(3,1,2)
row = df.loc[8][1:]
row.plot(kind='line',figsize=(15,5))
plt.subplot(3,1,3)
row = df.loc[9][1:]
row.plot(kind='line',figsize=(15,5))
plt.show()

# %%
plt.subplot(3,1,1)
row = df.loc[10][1:]
row.plot(kind='line',figsize=(15,5))
plt.subplot(3,1,2)
row = df.loc[11][1:]
row.plot(kind='line',figsize=(15,5))
plt.subplot(3,1,3)
row = df.loc[12][1:]
row.plot(kind='line',figsize=(15,5))
plt.show()

# %%
plt.subplot(3,1,1)
row = df.loc[1000][1:]
row.plot(kind='line',figsize=(15,5))
plt.subplot(3,1,2)
row = df.loc[1001][1:]
row.plot(kind='line',figsize=(15,5))
plt.subplot(3,1,3)
row = df.loc[2000][1:]
row.plot(kind='line',figsize=(15,5))
plt.show()

# %%
row.dtype
# Out:
# dtype('O')

# %%
row.diff().plot(kind='line',figsize=(15,5))
plt.show()

# %%
row = df.loc[0][1:]
plt.subplot(2,1,1)
row.plot(kind='line',figsize=(15,5))
plt.subplot(2,1,2)
row.diff().plot(kind='line',figsize=(15,5))
plt.show()

# %%
row.mean()
# Out:
# 21.756363636363638

# %%
lst = []
for i in range(0,100):
    row = df.loc[i][1:]
    lst.append(row.mean())

series = pd.Series(lst)
plt.subplot(1,2,1)
series.plot(kind='hist',figsize=(15,5))
plt.subplot(1,2,2)
series.plot(kind='kde')
plt.show()

# %%
plt.subplot(1,2,1)
series.plot(kind='pie',figsize=(15,5))
plt.subplot(1,2,2)
series.plot(kind='box')
plt.show()
